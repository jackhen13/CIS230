# %% [markdown]
# # Jackson Henry
# ## Wk4: 09/17/2026
# ### Python Dictionaries, {}, dict()

# %% [markdown]
# **Dictionary**
#
# - A dictionary is a collection that is unordered and changeable.
# - Dictionaries store data values in *key: value* pairs.
# - No Key Duplicates: Cannot have two items with the same key.
# - Changeable - can change: add remove, update items after the dictionary is created.
# - Item: key: value pairs

# %%
d = {'key1':'value1','key2':'value2','key3':'value3','key4':'value1','key1':'value5'}
d
# Out:
# {'key1': 'value5', 'key2': 'value2', 'key3': 'value3', 'key4': 'value1'}

# %%
len(d)
# Out:
# 4

# %%
car_dict={'brand':'Ford','model':'F-150','Year':2006}

# %%
len(car_dict)
# Out:
# 3

# %%
car_dict.items()
# Out:
# dict_items([('brand', 'Ford'), ('model', 'F-150'), ('Year', 2006)])

# %%
car_dict.keys()
# Out:
# dict_keys(['brand', 'model', 'Year'])

# %%
car_dict.values()
# Out:
# dict_values(['Ford', 'F-150', 2006])

# %%
cis_dict={'no':15,'cis':[200,230,240,340,350,360], 'crn':{'001','002','003','006','009',}}

# %%
cis_dict
# Out:
# {'no': 15,
#  'cis': [200, 230, 240, 340, 350, 360],
#  'crn': {'001', '002', '003', '006', '009'}}

# %%
len(cis_dict)
# Out:
# 3

# %%
car_dict
# Out:
# {'brand': 'Ford', 'model': 'F-150', 'Year': 2006}

# %%
cis_dict
# Out:
# {'no': 15,
#  'cis': [200, 230, 240, 340, 350, 360],
#  'crn': {'001', '002', '003', '006', '009'}}

# %%
# access to dict by keys, placing the keys in []
d['key1']
# Out:
# 'value5'

# %%
car_dict['brand']
# Out:
# 'Ford'

# %%
cis_dict['crn']
# Out:
# {'001', '002', '003', '006', '009'}

# %%
car_dict['Year']
# Out:
# 2006

# %%
cis_dict['cis']
# Out:
# [200, 230, 240, 340, 350, 360]

# %%
cis_dict['crn']
# Out:
# {'001', '002', '003', '006', '009'}

# %%
cis_dict['cis'][-3:]
# Out:
# [340, 350, 360]

# %%
cis_dict['no']
# Out:
# 15

# %%
cis_dict['no']=12

# %%
cis_dict
# Out:
# {'no': 12,
#  'cis': [200, 230, 240, 340, 350, 360],
#  'crn': {'001', '002', '003', '006', '009'}}

# %%
d
# Out:
# {'key1': 'value5', 'key2': 'value2', 'key3': 'value3', 'key4': 'value1'}

# %%
d['key4']=(1,2,3,4,5)

# %%
d
# Out:
# {'key1': 'value5', 'key2': 'value2', 'key3': 'value3', 'key4': (1, 2, 3, 4, 5)}

# %%
d['k3']= 'Henry'

# %%
d
# Out:
# {'key1': 'value5',
#  'key2': 'value2',
#  'key3': 'value3',
#  'key4': (1, 2, 3, 4, 5),
#  'k3': 'Henry'}

# %%
car_dict
# Out:
# {'brand': 'Ford', 'model': 'F-150', 'Year': 2006}

# %%
car_dict['color']='Black'

# %%
car_dict
# Out:
# {'brand': 'Ford', 'model': 'F-150', 'Year': 2006, 'color': 'Black'}

# %%
car_dict['color']='yellow'

# %%
car_dict
# Out:
# {'brand': 'Ford', 'model': 'F-150', 'Year': 2006, 'color': 'yellow'}
