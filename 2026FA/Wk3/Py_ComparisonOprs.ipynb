# %% [markdown]
# # Jackson Henry
# ## Week 3 - 09/10/2026
# ### Python Comparison Operators - Boolean

# %%
6 > 4
# Out:
# True

# %%
a, b = 5, 8

# %%
a < b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
b>= a
# Out:
# True

# %%
8 >= 8
# Out:
# True

# %%
a <= 5
# Out:
# True

# %%
c = 4

# %%
a
# Out:
# 5

# %%
b
# Out:
# 8

# %%
# and
5 > 3 and 8<9
# Out:
# True

# %%
False and True
# Out:
# False

# %%
a > c and c<b
# Out:
# True

# %%
(a>c)and (c<b)
# Out:
# True

# %%
(a>c)and (c>b)
# Out:
# False

# %%
# or
False or False
# Out:
# False

# %%
(a>c)or (c>=b)
# Out:
# True

# %%
# >,>=,<,<=,==,!=
# and, or, not

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
(5 < 6)
# Out:
# True

# %%
(5 < 6)
