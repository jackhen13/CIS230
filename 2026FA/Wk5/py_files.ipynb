# %% [markdown]
# # Jackson Henry
# ## wk5: 09/24/2026
# ### Python - Files and Data Basics

# %% [markdown]
# - Built-in magic commands %
# - Magics are specific to and provided by the IPython kernel
# - %% for multiple lines

# %%
# %%writefile filel.txt
# Hi, I am a student in CIS230
# I am using magic commands to create this file
# This is week 5
# We are using python to learn data analysis
# Out:
# Writing filel.txt

# %%
file_read = open('filel.txt','r')

# %%
file_read.read()
# Out:
# 'Hi, I am a student in CIS230\nI am using magic commands to create this file\nThis is week 5\nWe are using python to learn data analysis\n'

# %%
file_read.read()
# Out:
# ''

# %%
file_read.seek(0)
# Out:
# 0

# %%
file_read.read()
# Out:
# 'Hi, I am a student in CIS230\nI am using magic commands to create this file\nThis is week 5\nWe are using python to learn data analysis\n'

# %%
file_read.read()
# Out:
# ''

# %%
file_read.seek(0)
# Out:
# 0

# %%
file_read.readline()
# Out:
# 'Hi, I am a student in CIS230\n'

# %%
file_read.readline()
# Out:
# 'I am using magic commands to create this file\n'

# %%
file_read.readline()
# Out:
# 'This is week 5\n'

# %%
file_read.readline()
# Out:
# 'We are using python to learn data analysis\n'

# %%
file_read.readline()
# Out:
# ''

# %%
file_read.seek(0)
# Out:
# 0

# %%
file_read.readlines()
# Out:
# ['Hi, I am a student in CIS230\n',
#  'I am using magic commands to create this file\n',
#  'This is week 5\n',
#  'We are using python to learn data analysis\n']

# %%
file_read.readlines()
# Out:
# []

# %%
file_read.seek(0)
lst=file_read.readlines()
lst
# Out:
# ['Hi, I am a student in CIS230\n',
#  'I am using magic commands to create this file\n',
#  'This is week 5\n',
#  'We are using python to learn data analysis\n']

# %%
type(lst)
# Out:
# list

# %%
file_read.write('We are in clasroom 43!')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-22-e35fec3af35f> in <module>
# ----> 1 file_read.write('We are in clasroom 43!')
#
# UnsupportedOperation: not writable

# %%
file_read.close() # Very important to close files when you are done

# %%
file_append=open('filel.txt',"a+")

# %%
file_append.write("\nAdd line 1")
file_append.write("\nAdd line 2")
file_append.write("\nAdd line 3")
# Out:
# 11

# %%
file_append.read()
# Out:
# ''

# %%
file_append.seek(0)
file_append.read()
# Out:
# 'Hi, I am a student in CIS230\nI am using magic commands to create this file\nThis is week 5\nWe are using python to learn data analysis\n\nAdd line 1\nAdd line 2\nAdd line 3'

# %%
file_append.close()

# %%
file_overwrite=open('filel.txt','w+')

# %%
file_overwrite.write('line l\n')
# Out:
# 7

# %%
file_overwrite.seek(0)
file_overwrite.read()
# Out:
# 'line l\n'

# %%
file_overwrite.write('line 2\n')
file_overwrite.write('line 3\n')
file_overwrite.write('line 4\n')
# Out:
# 7

# %%
file_overwrite.seek(0)
file_overwrite.read()
# Out:
# 'line l\nline 2\nline 3\nline 4\n'

# %%
file_overwrite.write('1,2,3,4,5,6')
file_overwrite.write('\n1,2,3,4,5,6')
# Out:
# 12

# %%
file_overwrite.seek(0)
file_overwrite.read()
# Out:
# 'line l\nline 2\nline 3\nline 4\n1,2,3,4,5,6\n1,2,3,4,5,6'

# %%
file_overwrite.seek(0)
file_overwrite.read().split('\n')[4]
# Out:
# '1,2,3,4,5,6'

# %%
file_overwrite.close()

# %%
# json files
import json

# %%
data = {
    "name":"Alice",
    "age":"30",
    "skills":["Python","Data Science"]
}
type(data)
# Out:
# dict

# %%
# open a json file for writing
file=open('data.json','w')

json.dump(data,file,indent=6)

file.close()

# %%
file=open('data.json','r')
loaded_data=json.load(file)
file.close() # # Always close the file manually when not using it

# %%
loaded_data
# Out:
# {'name': 'Alice', 'age': '30', 'skills': ['Python', 'Data Science']}

# %%
type(loaded_data)
# Out:
# dict

# %%
loaded_data['skills']
# Out:
# ['Python', 'Data Science']
