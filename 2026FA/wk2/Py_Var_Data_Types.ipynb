# %% [markdown]
# # Jackson Henry
# ## Wk2: 09/01/2026
# ### Python Variables-Data types

# %% [markdown]
# ** Primitive data types **
#
# Python has four primitive data types:
#
# -Integer
# -Float
# -String
# -Boolean

# %%
type(5)
# Out:
# int

# %%
type(5.5)
# Out:
# float

# %%
type("Hi, I am a student in CIS230")
# Out:
# str

# %%
type("CIS 230 is a data analysis class!")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
#using variables
courses=5

# %%
Scources=5

# %%
_courses=5

# %%
my_gpa=3.98

# %%
my gpa=3.98
# Out:
#   File "<ipython-input-20-260c5c593cca>", line 1
#     my gpa=3.98
#          ^
# SyntaxError: invalid syntax

# %%
myAccount="123456"

# %%
courses
# Out:
# 5

# %%
_courses
# Out:
# 5

# %%
my_gpa
# Out:
# 3.98

# %%
courses=6

# %%
courses
# Out:
# 6

# %%
myAccount="456789"

# %%
myAccount
# Out:
# '456789'

# %%
x=5

# %%
x=x+5

# %%
x
# Out:
# 10

# %%
x*2
# Out:
# 20

# %%
x
# Out:
# 10

# %%
x=x*3

# %%
x
# Out:
# 30

# %%
num_hours = 10
pay_rate = 15.60
total_pay = num_hours * pay_rate

# %%
num_hours
# Out:
# 10

# %%
pay_rate
# Out:
# 15.6

# %%
total_pay
# Out:
# 156.0

# %%
account_number="12345"

# %%
type(account_number)
# Out:
# str

# %%
# print a statement to format output
print("My total Pay: ", total_pay)
# Out:
# My total Pay:  156.0

# %%
# Compute the average of three courses grades [0 and 100]
course1=75
course2=87
course3=60
average=(course1+course2+course3)/3
print("the average of the 3 courses: ", average)
# Out:
# the average of the 3 courses:  74.0
