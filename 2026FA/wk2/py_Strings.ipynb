# %% [markdown]
# # Jackson Henry
# ## Wk2: 09/03/2026
# ### Python string data type

# %%
a="one way of writing a string"
b="another way"

# %%
print(a)
# Out:
# one way of writing a string

# %%
print(b)
# Out:
# another way

# %%
b
# Out:
# 'another way'

# %%
# Single quote and double quote - Apostrophe
m = 'I'm using python language in CIS230'
# Out:
#   File "<ipython-input-6-12e35bd563ef>", line 2
#     m = 'I'm using python language in CIS230'
#            ^
# SyntaxError: invalid syntax

# %%
"I'm using python language in CIS230"
# Out:
# "I'm using python language in CIS230"

# %%
print(m)
# Out:
# I'm using python language in CIS230

# %%
m='I\'m using python language in \t CIS230'

# %%
print(m)
# Out:
# I'm using python language in 	 CIS230

# %%
print("CIS230 is: a networking cloud class")
# Out:
# CIS230 is: a networking cloud class

# %%
print('CIS230 is:\n a networking and cloud class')
# Out:
# CIS230 is:
#  a networking and cloud class

# %%
m
# Out:
# "I'm using python language in \t CIS230"

# %%
len(m)
# Out:
# 37

# %%
len('CIS230 is Python class!')
# Out:
# 23

# %%
# String Indexing
m='CIS230 is Python class!'
m
# Out:
# 'CIS230 is Python class!'

# %%
len(m)
# Out:
# 23

# %%
m[0]
# Out:
# 'C'

# %%
m[22]
# Out:
# '!'

# %%
m[17]
# Out:
# 'c'

# %%
m[16]
# Out:
# ' '

# %%
m
# Out:
# 'CIS230 is Python class!'

# %%
m[-1]
# Out:
# '!'

# %%
m[-2]
# Out:
# 's'

# %%
m[-3]
# Out:
# 's'

# %%
m[-23]
# Out:
# 'C'

# %%
# String slicing
# [Start:End:Step]
# Start: Default start 0
# End: default end last char index, (exclusive of string Length)
# Step: Default step is 1
m
# Out:
# 'CIS230 is Python class!'

# %%
m[0:6]
# Out:
# 'CIS230'

# %%
m[:6]
# Out:
# 'CIS230'

# %%
m[17:24]
# Out:
# 'class!'

# %%
m[5:17]
# Out:
# '0 is Python '

# %%
m[::]
# Out:
# 'CIS230 is Python class!'

# %%
m[::2]
# Out:
# 'CS3 sPto ls!'

# %%
m[::3]
# Out:
# 'C2  tnls'

# %%
m
# Out:
# 'CIS230 is Python class!'

# %%
# reverse indexing
m[-6:]
# Out:
# 'class!'

# %%
m[-6:-1]
# Out:
# 'class'

# %%
m[-20:-5]
# Out:
# '230 is Python c'

# %%
m[-23:-10:2]
# Out:
# 'CS3 sPt'

# %%
m
# Out:
# 'CIS230 is Python class!'

# %%
m[::-1] # read in a reverse order
# Out:
# '!ssalc nohtyP si 032SIC'

# %%
# using some string methods (Built in functions)
x="welcome to CIS 230, a date analysis class-fall 2026"
x
# Out:
# 'welcome to CIS 230, a date analysis class-fall 2026'

# %%
x.title()
# Out:
# 'Welcome To Cis 230, A Date Analysis Class-Fall 2026'

# %%
t = x.title()

# %%
t
# Out:
# 'Welcome To Cis 230, A Date Analysis Class-Fall 2026'

# %%
x.capitalize()
# Out:
# 'Welcome to cis 230, a date analysis class-fall 2026'

# %%
x.upper()
# Out:
# 'WELCOME TO CIS 230, A DATE ANALYSIS CLASS-FALL 2026'

# %%
x.lower()
# Out:
# 'welcome to cis 230, a date analysis class-fall 2026'

# %%
x.
